# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from Analisis_Predictivo import Analisis_Predictivo
from Analisis_Predictivo import Graficar
from sklearn.ensemble import AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis

import os
os.chdir("/home/william/Desktop")
from Analisis_Predictivo import GraficarROC

# %%
potabilidad = pd.read_csv("potabilidad_V2.csv")
potabilidad = potabilidad.iloc[:,1:]
potabilidad["Potability"] = potabilidad["Potability"].astype('category')

# %%
decisionTree =  DecisionTreeClassifier()
analisisDecisionTree = Analisis_Predictivo(potabilidad,predecir= "Potability",modelo=decisionTree, train_size= 0.80)
analisisDecisionTree.training_testing_con_reja_corte(corte=[0.20, 0.30, 0.40, 0.50, 0.60, 0.70, 0.80, 0.90], model=decisionTree)
# Out:
# ===========================
# Probabilidad de Corte:  0.2
#
# Matriz de Confusión:
# [[167  66]
#  [ 87  83]]
#
# Precisión Global:
# 0.6203473945409429
#
# Error Global:
# 0.3796526054590571
#
# Precisión por categoría:
#          No        Si
# 0  0.716738  0.488235
# ===========================
# Probabilidad de Corte:  0.3
#
# Matriz de Confusión:
# [[167  66]
#  [ 87  83]]
#
# Precisión Global:
# 0.6203473945409429
#
# Error Global:
# 0.3796526054590571
#
# Precisión por categoría:
#          No        Si
# 0  0.716738  0.488235
# ===========================
# Probabilidad de Corte:  0.4
#
# Matriz de Confusión:
# [[167  66]
#  [ 87  83]]
#
# Precisión Global:
# 0.6203473945409429
#
# Error Global:
# 0.3796526054590571
#
# Precisión por categoría:
#          No        Si
# 0  0.716738  0.488235
# ===========================
# Probabilidad de Corte:  0.5
#
# Matriz de Confusión:
# [[167  66]
#  [ 87  83]]
#
# Precisión Global:
# 0.6203473945409429
#
# Error Global:
# 0.3796526054590571
#
# Precisión por categoría:
#          No        Si
# 0  0.716738  0.488235
# ===========================
# Probabilidad de Corte:  0.6
#
# Matriz de Confusión:
# [[167  66]
#  [ 87  83]]
#
# Precisión Global:
# 0.6203473945409429
#
# Error Global:
# 0.3796526054590571
#
# Precisión por categoría:
#          No        Si
# 0  0.716738  0.488235
# ===========================
# Probabilidad de Corte:  0.7
#
# Matriz de Confusión:
# [[167  66]
#  [ 87  83]]
#
# Precisión Global:
# 0.6203473945409429
#
# Error Global:
# 0.3796526054590571
#
# Precisión por categoría:
#          No        Si
# 0  0.716738  0.488235
# ===========================
# Probabilidad de Corte:  0.8
#
# Matriz de Confusión:
# [[167  66]
#  [ 87  83]]
#
# Precisión Global:
# 0.6203473945409429
#
# Error Global:
# 0.3796526054590571
#
# Precisión por categoría:
#          No        Si
# 0  0.716738  0.488235
# ===========================
# Probabilidad de Corte:  0.9
#
# Matriz de Confusión:
# [[167  66]
#  [ 87  83]]
#
# Precisión Global:
# 0.6203473945409429
#
# Error Global:
# 0.3796526054590571
#
# Precisión por categoría:
#          No        Si
# 0  0.716738  0.488235

# %%
extremeGradiantBoosting = GradientBoostingClassifier()
analisisGradiantBoosting = Analisis_Predictivo(potabilidad,predecir= "Potability",modelo=extremeGradiantBoosting, train_size= 0.80)
analisisGradiantBoosting.training_testing_con_reja_corte(corte=[0.20, 0.30,0.40, 0.50, 0.60, 0.70, 0.80, 0.90], model=extremeGradiantBoosting)
# Out:
# ===========================
# Probabilidad de Corte:  0.2
#
# Matriz de Confusión:
# [[ 16 226]
#  [  7 154]]
#
# Precisión Global:
# 0.4218362282878412
#
# Error Global:
# 0.5781637717121588
#
# Precisión por categoría:
#          No        Si
# 0  0.066116  0.956522
# ===========================
# Probabilidad de Corte:  0.3
#
# Matriz de Confusión:
# [[ 65 177]
#  [ 39 122]]
#
# Precisión Global:
# 0.4640198511166253
#
# Error Global:
# 0.5359801488833746
#
# Precisión por categoría:
#          No        Si
# 0  0.268595  0.757764
# ===========================
# Probabilidad de Corte:  0.4
#
# Matriz de Confusión:
# [[148  94]
#  [ 72  89]]
#
# Precisión Global:
# 0.5880893300248139
#
# Error Global:
# 0.4119106699751861
#
# Precisión por categoría:
#         No        Si
# 0  0.61157  0.552795
# ===========================
# Probabilidad de Corte:  0.5
#
# Matriz de Confusión:
# [[199  43]
#  [112  49]]
#
# Precisión Global:
# 0.6153846153846154
#
# Error Global:
# 0.3846153846153846
#
# Precisión por categoría:
#          No        Si
# 0  0.822314  0.304348
# ===========================
# Probabilidad de Corte:  0.6
#
# Matriz de Confusión:
# [[226  16]
#  [128  33]]
#
# Precisión Global:
# 0.6426799007444168
#
# Error Global:
# 0.35732009925558317
#
# Precisión por categoría:
#          No        Si
# 0  0.933884  0.204969
# ===========================
# Probabilidad de Corte:  0.7
#
# Matriz de Confusión:
# [[240   2]
#  [145  16]]
#
# Precisión Global:
# 0.6352357320099256
#
# Error Global:
# 0.36476426799007444
#
# Precisión por categoría:
#          No        Si
# 0  0.991736  0.099379
# ===========================
# Probabilidad de Corte:  0.8
#
# Matriz de Confusión:
# [[241   1]
#  [151  10]]
#
# Precisión Global:
# 0.6228287841191067
#
# Error Global:
# 0.3771712158808933
#
# Precisión por categoría:
#          No        Si
# 0  0.995868  0.062112
# ===========================
# Probabilidad de Corte:  0.9
#
# Matriz de Confusión:
# [[242   0]
#  [158   3]]
#
# Precisión Global:
# 0.607940446650124
#
# Error Global:
# 0.39205955334987597
#
# Precisión por categoría:
#     No        Si
# 0  1.0  0.018634

# %% [markdown]
# Como pueden ver, si cambio bastante, mientras que para el decision tree todas las interaciones son iguales, en el XG Boosting son bastantes diferentes, de hecho se puede ver que segun la probabilidad de corte cambia en casi todas las iteraciones

# %%
bayes = GaussianNB()
knn_model =  KNeighborsClassifier(n_neighbors=60, algorithm="auto")
decisionTree =  DecisionTreeClassifier(criterion="gini")
adaBoosting = AdaBoostClassifier()
extremeGradiantBoosting = GradientBoostingClassifier()
lda = LinearDiscriminantAnalysis()
qda = QuadraticDiscriminantAnalysis()
analisis = Analisis_Predictivo(potabilidad,predecir= "Potability",modelo=lda,
                                       train_size= 0.75)

# %%
graficarROC = GraficarROC(models=[bayes, knn_model, decisionTree, adaBoosting, extremeGradiantBoosting, lda, qda], label=["bayes", "knn_model", "decisionTree", "adaBoosting", "extremeGradiantBoosting", "lda", "qda"],color=["red","green","purple", "yellow", "blue", "black", "purple"], x=analisis.x, y=analisis.y, predecir="Potability")
graficarROC.graficar()

# %% [markdown]
# Se puede concluir que el mejor que QDA modelo es el mejor modelo posible para este conjunto de datos
